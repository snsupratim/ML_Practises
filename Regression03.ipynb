# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset.csv')
df.head()
# Out:
#    Patient ID  Age  Blood Pressure  Cholesterol Levels  Heart Rate   BMI  \
# 0         101   65             130                 250          72  28.0
# 1         102   42             110                 150          76  24.0
# 2         103   58             140                 200          80  30.0
# 3         104   71             160                 220          88  32.0
# 4         105   35             120                 180          74  27.0
#
#                              Diagnosis  \
# 0  Hypertension with high cholesterol.
# 1                    Pre-hypertension.
# 2                     Type 2 Diabetes.
# 3                       Heart Failure.
# 4                          Overweight.
#
#                                       Treatment Plan  Recovery Status  \
# 0  Medication: Lisinopril (blood pressure), Stati...  Active Recovery
# 1  Lifestyle modification: Regular exercise, heal...        Recovered
# 2  Medication: Metformin (blood sugar control). L...  Active Recovery
# 3  Medication: Digoxin (heart function), Furosemi...  Active Recovery
# 4  Lifestyle modification: Regular exercise, heal...        Recovered
#
#         Medication Type Follow-up Requirement
# 0  Lisinopril, Statins.            Quarterly.
# 1                  N/A.           Six months.
# 2            Metformin.            Quarterly.
# 3  Digoxin, Furosemide.              Monthly.
# 4                  N/A.         Three months.

# %%
meddata=df[['Blood Pressure','Cholesterol Levels','Heart Rate','BMI','Age']]
meddata.head()
# Out:
#    Blood Pressure  Cholesterol Levels  Heart Rate   BMI  Age
# 0             130                 250          72  28.0   65
# 1             110                 150          76  24.0   42
# 2             140                 200          80  30.0   58
# 3             160                 220          88  32.0   71
# 4             120                 180          74  27.0   35

# %%
X=df[['Blood Pressure','Cholesterol Levels','Heart Rate','BMI']]
Y=df['Age']

# %%
X
# Out:
#     Blood Pressure  Cholesterol Levels  Heart Rate   BMI
# 0              130                 250          72  28.0
# 1              110                 150          76  24.0
# 2              140                 200          80  30.0
# 3              160                 220          88  32.0
# 4              120                 180          74  27.0
# ..             ...                 ...         ...   ...
# 95             140                 260          85  32.0
# 96             125                 200          70  25.0
# 97             115                 180          80  24.0
# 98             120                 190          75  23.0
# 99             120                 240          80  28.0
#
# [100 rows x 4 columns]

# %%
Y
# Out:
# 0     65
# 1     42
# 2     58
# 3     71
# 4     35
#       ..
# 95    45
# 96    70
# 97    55
# 98    30
# 99    45
# Name: Age, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression

mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mlr.predict(x_test)
y_pred
# Out:
# array([47.27156947, 76.09855234, 40.72180429, 43.18789558, 63.52005642,
#        56.16662066, 58.39078183, 58.45794236, 44.0034264 , 53.95080514,
#        51.4625696 , 29.15878131, 49.86551246, 51.8157027 , 40.36194434,
#        33.27930981, 45.19190873, 50.77010201, 50.77010201, 35.49839967])

# %%
r_sq=mlr.score(X,Y)
print(r_sq)
# Out:
# 0.623017237348849
